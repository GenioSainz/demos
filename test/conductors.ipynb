# %%
from pyampacity.utils.get_models import get_models_obj

model = get_models_obj( standard="CIGRE601", conductor_name="LA280-Hawk") 
model.conductor.__dict__
# Out:
# {'conductor_name': 'LA280-Hawk',
#  'solar_absorptivity': 0.8,
#  'emissivity': 0.8,
#  'diameter_D': np.float64(0.02179),
#  'diameter_d': np.float64(0.00344),
#  'diameter_c': np.float64(0.00802),
#  'Rac_at_temp1': np.float64(0.00011992),
#  'Rac_at_temp2': np.float64(0.00014354),
#  'temp1_Rac': 25,
#  'temp2_Rac': 75,
#  'conductor_max_temperature': 100,
#  'beta20_a': 0.00038,
#  'beta20_s': 0.0001,
#  'c20_a': 897,
#  'c20_s': 481,
#  'ma': np.float64(0.66759),
#  'ms': np.float64(0.30716000000000004),
#  'm': np.float64(0.97475)}
